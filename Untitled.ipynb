# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("avocado.csv") 

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
In [1]: import numpy as np

# %%
In [3]: s = pd.Series([1, 3, 5, np.nan, 6, 8])

In [4]: s
Out[4]: 
0    1.0
1    3.0
2    5.0
3    NaN
4    6.0
5    8.0
dtype: float64
# Out:
#   File "C:\Users\erick\AppData\Local\Temp\ipykernel_25144\235480988.py", line 4
#     Out[4]:
#             ^
# SyntaxError: invalid syntax

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\erick'

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\972437606.py in <module>
# ----> 1 df.mean()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
col1= df['Small Bags']
col2= df['Large Bags']
col3= df['XLarge Bags']
myData= [col1,col2,col3]
fig = plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
bp = ax.boxplot(myData)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\82631176.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 col1= df['Small Bags']
#       3 col2= df['Large Bags']
#       4 col3= df['XLarge Bags']
#       5 myData= [col1,col2,col3]
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
col1= data['Small Bags']
col2= data['Large Bags']
col3= data['XLarge Bags']
myData= [col1,col2,col3]
fig = plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
bp = ax.boxplot(myData)
plt.show()

# %%
# Out:
# C:\Users\erick\AppData\Local\Temp\ipykernel_25144\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Unnamed: 0          24.232232
# AveragePrice         1.405978
# Total Volume    850644.013009
# 4046            293008.424531
# 4225            295154.568356
# 4770             22839.735993
# Total Bags      239639.202060
# Small Bags      182194.686696
# Large Bags       54338.088145
# XLarge Bags       3106.426507
# year              2016.147899
# dtype: float64

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Con Describe podemos ver las variables y en que rango se encuentran

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
data.iloc[1:3, :]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume    4046       4225  \
# 1           1  2015-12-20          1.35      54876.98  674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22  794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 1  2015  Albany
# 2  2015  Albany

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
import matplotlib.pyplot as plt
col1= data['Small Bags']
col2= data['Large Bags']
col3= data['XLarge Bags']
myData= [col1,col2,col3]
fig = plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
bp = ax.boxplot(myData)
plt.show()

# %% [markdown]
# En esta gráfica se muestran datos de 3 columnas: Small bags,Large Bags,Xlarge bags

# %%
# Implementation of matplotlib function
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10**7)
mu = 121
sigma = 21
x = mu + sigma * np.random.randn(1000)

num_bins = 100

n, bins, patches = plt.hist(x, num_bins,
							density = 1,
							color ='green',
							alpha = 0.7)

y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
	np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

plt.plot(bins, y, '--', color ='black')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.title('matplotlib.pyplot.hist() function Example\n\n',
		fontweight ="bold")

plt.show()

# %% [markdown]
# Aquí podemos ver una implementación de la función HIST

# %% [markdown]
# Otra implementación de hist

# %%
# Implementation of matplotlib function
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
	
np.random.seed(10**7)
n_bins = 20
x = np.random.randn(10000, 3)
	
colors = ['green', 'blue', 'lime']

plt.hist(x, n_bins, density = True,
		histtype ='bar',
		color = colors,
		label = colors)

plt.legend(prop ={'size': 10})

plt.title('matplotlib.pyplot.hist() function Example\n\n',
		fontweight ="bold")

plt.show()

# %%
# libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load data set
df = sns.load_dataset('iris')

# Basic correlogram
sns.pairplot(df)
plt.show()

# %% [markdown]
# Aquí podemos ver el uso del coeficiente de correlación. Los datos estan muy esparcidos
